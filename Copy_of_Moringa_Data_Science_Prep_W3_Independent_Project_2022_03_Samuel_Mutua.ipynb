# %% [markdown]
# <a href="https://colab.research.google.com/github/Sammy-Mutua/Independent_Project/blob/main/Copy_of_Moringa_Data_Science_Prep_W3_Independent_Project_2022_03_Samuel_Mutua.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
# Loading our data set
# 1.
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-bee3fa5c-cf62-484b-9f6f-8f5768e4ab83" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bee3fa5c-cf62-484b-9f6f-8f5768e4ab83">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cells_geo_description.xlsx to cells_geo_description.xlsx

# %%
df1 = pd.DataFrame(pd.read_excel("cells_geo_description.xlsx"))
df1
# Out:
#      Column name                                        Description  Format
# 0         VILLES                                               City  String
# 1         STATUS                                  In Service or not  String
# 2   LOCALISATION                                  in ABIDJAN or not  String
# 3     DECOUPZONE                                  Geographical Zone  String
# 4       ZONENAME                                       Name of Zone  String
# 5      LONGITUDE                                          Longitude   Float
# 6       LATITUDE                                           Latitude   Float
# 7         REGION                                             Region  String
# 8           AREA                                               Area  String
# 9        CELL_ID                                     ID of the cell  String
# 10     SITE_CODE  Site (there are several cells per site, severa...  String

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-99e4f5e0-1ca6-4b8d-ab86-03bb0dbbabd0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-99e4f5e0-1ca6-4b8d-ab86-03bb0dbbabd0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cells_geo.csv to cells_geo.csv

# %%
from pandas._libs.algos import diff_2d

df2 = pd.read_csv('cells_geo.csv',delimiter=';', names = ['City','Status','Locality','Geographical_Zone','Zone_Name','Longitude','Latitude','Region','Area','Cell_ID','Site_ID'])
df2.head()
# Out:
#         City      Status      Locality Geographical_Zone Zone_Name  \
# NaN   VILLES      STATUS  LOCALISATION        DECOUPZONE  ZONENAME
# 0.0   ADJAME  In Service       ABIDJAN      "Abidjan_EST  AGBANNEW
# 1.0   ADJAME  In Service       ABIDJAN      "Abidjan_EST  AGBANNEW
# 2.0   ADJAME  In Service       ABIDJAN      "Abidjan_EST  AGBANNEW
# 3.0  ASSINIE  In Service     INTERIEUR         Grand-EST  ASSINIE"
#
#              Longitude          Latitude     Region  Area     Cell_ID  \
# NaN          LONGITUDE          LATITUDE     REGION  AREA     CELL_ID
# 0.0  -4.00066666666667  5.36819444444444     LAGUNE   NaN  fbb2e75af3
# 1.0  -4.00066666666667  5.36819444444444     LAGUNE   NaN  1502501d78
# 2.0  -4.00066666666667  5.36819444444444     LAGUNE   NaN  0c2e182a0c
# 3.0  -3.48846666666667  5.15876111111111  SUD COMOE   NaN  69bdfc69fd
#
#         Site_ID
# NaN   SITE_CODE
# 0.0  0bb492ef17
# 1.0  0bb492ef17
# 2.0  0bb492ef17
# 3.0  8a1e6ce31f

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-200da177-21b5-48e0-b8ec-a2f354a1a5a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-200da177-21b5-48e0-b8ec-a2f354a1a5a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CDR_description.xlsx to CDR_description.xlsx

# %%
df3 = pd.DataFrame(pd.read_excel("CDR_description.xlsx"))
df3
# Out:
#        Column name                                        Description   Format
# 0          PRODUCT                                       Voice or SMS   String
# 1            VALUE                                      Billing price  Integer
# 2        DATE_TIME               Time in format yyyy-MM-dd hh:mm:ss.0   String
# 3     CELL_ON_SITE  Which cell in the site was used (not needed here)  Integer
# 4  DW_A_NUMBER_INT  Anonymized phone number of the person for whic...   String
# 5  DW_B_NUMBER_INT        Anonymized phone number of the counterparty   String
# 6        COUNTRY_A                  Country of party A (useless here)   String
# 7        COUNTRY_B                  Country of party B (useless here)   String
# 8          CELL_ID                                     ID of the cell   String
# 9          SITE_ID                                     ID of the SITE   String

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-6565e99d-e8ab-4585-9561-17060489bacd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6565e99d-e8ab-4585-9561-17060489bacd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Telcom_dataset.csv to Telcom_dataset (1).csv

# %%
df4 = pd.read_csv('Telcom_dataset.csv')

df4.head()
# Out:
#   PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0   Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1     sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2     sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3   Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4   Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
#
#    DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1  93343ba6e41af95     19e2e     19e2e  /+cKZKIp41  /+cKZKIp41
# 2  7aacc9709ce0a20     19e2e     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3  6af4a60e74c91d3     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  02aa736ee555d5c     19e2e     19e2e  051KhYDCpv  051KhYDCpv

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-93f6beed-bbd3-4d8e-bd32-f341ac69561e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93f6beed-bbd3-4d8e-bd32-f341ac69561e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Telcom_dataset2.csv to Telcom_dataset2 (1).csv

# %%
df5 = pd.read_csv('Telcom_dataset2.csv')

df5.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME CELL_ON_SITE      DW_A_NUMBER  \
# 0     sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1   Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2     sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3   Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4     sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
#
#        DW_B_NUMBER COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1aa7ae01386e9fb     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 1  87d87309c15a8c9     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 2  93343ba6e41af95     19e2e     19e2e  +laSrk7g6q  +laSrk7g6q
# 3  7d05a38f89c49d8     19e2e     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4  56a5d5430d2fa86     19e2e     19e2e  +bO+qkSonO  +bO+qkSonO

# %%
from google.colab import files


uploaded = files.upload()
# Out:
#      <input type="file" id="files-e8d3940b-508b-4ffd-b233-2572318a90c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8d3940b-508b-4ffd-b233-2572318a90c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Telcom_dataset3.csv to Telcom_dataset3.csv

# %%
df6 = pd.read_csv('Telcom_dataset3.csv')
df6.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0   Voice     61  2012-05-08 23:01:28.0            2  966f68353622feb
# 1     sms      0  2012-05-08 23:01:31.0            1  a0a597384c612d7
# 2   Voice     10  2012-05-08 23:02:59.0            1  5441a9a58c97132
# 3     sms      0  2012-05-08 23:03:04.0            0  8ab8b9ed6989f61
# 4   Voice     22  2012-05-08 23:03:16.0            4  52662a62b199334
#
#    DW_B_NUMBER_INT COUNTRY_A COUNTRY_B      CELLID     SIET_ID
# 0  ffd53a3bb2db6f1     19e2e     19e2e  +38u2u/rfx  +38u2u/rfx
# 1  cf3b218f1dde792     19e2e     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2  52f8b299515b9b7     19e2e     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3  e09e736e46c5c3d     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  2186273faab4602     19e2e     19e2e  /eeMklgyJA  /eeMklgyJA

# %% [markdown]
# **DATA CLEANING**

# %%
df2. drop(df2. index[0])
# Out:
#             City      Status   Locality Geographical_Zone  \
# 0.0       ADJAME  In Service    ABIDJAN      "Abidjan_EST
# 1.0       ADJAME  In Service    ABIDJAN      "Abidjan_EST
# 2.0       ADJAME  In Service    ABIDJAN      "Abidjan_EST
# 3.0      ASSINIE  In Service  INTERIEUR         Grand-EST
# 4.0      ASSINIE  In Service  INTERIEUR         Grand-EST
# ...          ...         ...        ...               ...
# 3969.0  ZUENOULA  In Service  INTERIEUR        Grand-NORD
# 3970.0  ZUENOULA  In Service  INTERIEUR        Grand-NORD
# 3971.0  ZUENOULA  In Service  INTERIEUR        Grand-NORD
# 3972.0  ZUENOULA  In Service  INTERIEUR        Grand-NORD
# 3973.0  ZUENOULA  In Service  INTERIEUR        Grand-NORD
#
#                   Zone_Name          Longitude          Latitude     Region  \
# 0.0                AGBANNEW  -4.00066666666667  5.36819444444444     LAGUNE
# 1.0                AGBANNEW  -4.00066666666667  5.36819444444444     LAGUNE
# ...

# %%
# Out:
#   PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0   Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1     sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2     sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3   Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4   Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
#
#    DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID PRODUCT  \
# 0  1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu  /TJNe+Mmtu     NaN
# 1  93343ba6e41af95     19e2e     19e2e  /+cKZKIp41  /+cKZKIp41     NaN
# 2  7aacc9709ce0a20     19e2e     19e2e  /u0FSD+ahi  /u0FSD+ahi     NaN
# 3  6af4a60e74c91d3     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3     NaN
# 4  02aa736ee555d5c     19e2e     19e2e  051KhYDCpv  051KhYDCpv     NaN
#
#   DATE_TIME CELLID SIET_ID
# 0       NaN    NaN     NaN
# 1       NaN    NaN     NaN
# 2       NaN    NaN     NaN
# ...

# %%
df4 = pd.read_csv('Telcom_dataset.csv')

df4.head()
# Out:
#   PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0   Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1     sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2     sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3   Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4   Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
#
#    DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1a49f8b0ded9de6     19e2e     19e2e  /TJNe+Mmtu  /TJNe+Mmtu
# 1  93343ba6e41af95     19e2e     19e2e  /+cKZKIp41  /+cKZKIp41
# 2  7aacc9709ce0a20     19e2e     19e2e  /u0FSD+ahi  /u0FSD+ahi
# 3  6af4a60e74c91d3     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  02aa736ee555d5c     19e2e     19e2e  051KhYDCpv  051KhYDCpv

# %%
df5 = pd.read_csv('Telcom_dataset2.csv')

df5.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME CELL_ON_SITE      DW_A_NUMBER  \
# 0     sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1   Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2     sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3   Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4     sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
#
#        DW_B_NUMBER COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# 0  1aa7ae01386e9fb     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 1  87d87309c15a8c9     19e2e     19e2e  +854AcBQT2  +854AcBQT2
# 2  93343ba6e41af95     19e2e     19e2e  +laSrk7g6q  +laSrk7g6q
# 3  7d05a38f89c49d8     19e2e     19e2e  /xvRrCVKoQ  /xvRrCVKoQ
# 4  56a5d5430d2fa86     19e2e     19e2e  +bO+qkSonO  +bO+qkSonO

# %%
df6 = pd.read_csv('Telcom_dataset3.csv')

df6.head()
# Out:
#   PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0   Voice     61  2012-05-08 23:01:28.0            2  966f68353622feb
# 1     sms      0  2012-05-08 23:01:31.0            1  a0a597384c612d7
# 2   Voice     10  2012-05-08 23:02:59.0            1  5441a9a58c97132
# 3     sms      0  2012-05-08 23:03:04.0            0  8ab8b9ed6989f61
# 4   Voice     22  2012-05-08 23:03:16.0            4  52662a62b199334
#
#    DW_B_NUMBER_INT COUNTRY_A COUNTRY_B      CELLID     SIET_ID
# 0  ffd53a3bb2db6f1     19e2e     19e2e  +38u2u/rfx  +38u2u/rfx
# 1  cf3b218f1dde792     19e2e     19e2e  +Fs4mTvdKx  +Fs4mTvdKx
# 2  52f8b299515b9b7     19e2e     19e2e  +ZaaZozy/+  +ZaaZozy/+
# 3  e09e736e46c5c3d     19e2e     19e2e  +cNeJzsTp3  +cNeJzsTp3
# 4  2186273faab4602     19e2e     19e2e  /eeMklgyJA  /eeMklgyJA

# %%
combined = pd.concat([df4,df5,df6], ignore_index = 1)
combined.tail()
# Out:
#       PRODUTC  VALUE DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  DW_B_NUMBER_INT  \
# 14998     NaN      0      NaN            3  467333ade2b4b9c  0ab2acd804d01fe
# 14999     NaN     62      NaN            1  e077a6b74c5053c  4c8098eb6ea1a41
# 15000     NaN     32      NaN            1  77f53c39d27c050  9d064f013e2cab2
# 15001     NaN     30      NaN            2  672ce74c418aa7a  f9ff5af59cf0d68
# 15002     NaN     60      NaN            2  6edeb4c55714650  7e60838216482a7
#
#       COUNTRY_A COUNTRY_B CELL_ID SITE_ID PRODUCT              DATE_TIME  \
# 14998     19e2e     19e2e     NaN     NaN   Voice  2012-05-09 00:01:43.0
# 14999     19e2e     19e2e     NaN     NaN   Voice  2012-05-09 00:01:43.0
# 15000     19e2e     19e2e     NaN     NaN   Voice  2012-05-09 00:01:43.0
# 15001     19e2e     19e2e     NaN     NaN   Voice  2012-05-09 00:01:43.0
# 15002     19e2e     19e2e     NaN     NaN   Voice  2012-05-09 00:01:43.0
#
#       DW_A_NUMBER DW_B_NUMBER      CELLID     SIET_ID
# ...

# %% [markdown]
# **DATA UNDERSTANDING**

# %%
print(df2.info())
print(df2.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 3975 entries, nan to 3973.0
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               3975 non-null   object
#  1   Status             3908 non-null   object
#  2   Locality           3975 non-null   object
#  3   Geographical_Zone  3975 non-null   object
#  4   Zone_Name          3969 non-null   object
#  5   Longitude          3975 non-null   object
#  6   Latitude           3975 non-null   object
#  7   Region             3975 non-null   object
#  8   Area               3952 non-null   object
#  9   Cell_ID            3975 non-null   object
#  10  Site_ID            3975 non-null   object
# dtypes: object(11)
# memory usage: 501.7+ KB
# None
#           City      Status   Locality Geographical_Zone             Zone_Name  \
# count     3975        3908       3975              3975                  3969
# ...

# %%
print ("There are ", df2.Locality.nunique(), "Unique Localities  " "out of " , df2.Locality.count())
print ("There are ", df2.Area.nunique(), "Unique Area  out of " , df2.Area.count())
print ("There are  ", df2.Geographical_Zone.nunique(), "Unique Geographical_Zone out of " , df2.Geographical_Zone.count())
print ("There are ", df2.Region.nunique(), "Unique Regions  out of " , df2.Region.count())
print ("There are ", df2.City.nunique(), "Unique cities out of " , df2.City.count())
print ("There are ", df2.Site_ID.nunique(), "Unique Site_Id  out of " , df2.Site_ID.count())
print ("There are", df2.Cell_ID.nunique(), " Unique Cell_ID out of " , df2.Cell_ID.count())
# Out:
# There are  3 Unique Localities  out of  3975
# There are  7 Unique Area  out of  3952
# There are   16 Unique Geographical_Zone out of  3975
# There are  20 Unique Regions  out of  3975
# There are  505 Unique cities out of  3975
# There are  1030 Unique Site_Id  out of  3975
# There are 3917  Unique Cell_ID out of  3975
